# %%
print('Hello World!')

def sum(x, y):
  z = x + y
  print(z)

def hello(name):
  print("Hello, {name}!")

hello("Gunnar")
sum(3, 5)

# %%
l = [1, 'Hello', None, 2, 4]

res = 0 
for i in l:
  if type(i) == int:
    res += i

res
# Out:
# 7
